# %% [markdown]
# # Phase 9.1: Trajectory Construction
#
# This notebook verifies that trajectory data is correctly processed and formatted.

# %%
import pandas as pd
import os

# Ensure results directory exists
os.makedirs('../results/projected', exist_ok=True)

# Trajectories logic depends on PCA and UMAP pre-computed models which are already correctly placed in results/projected/
assert os.path.exists('../results/projected/gpt2_pca.parquet')
assert os.path.exists('../results/projected/gpt2_umap.parquet')
print("Trajectories verified.")
# Out:
# Trajectories verified.
