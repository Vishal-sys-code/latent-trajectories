# %% [markdown]
# # Phase 9: Key Figures
#
# This notebook generates the 5 key figures required for the workshop paper submission.

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (2.4.6)
# Requirement already satisfied: pandas in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: torch in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (2.12.0)
# Requirement already satisfied: transformers in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 4)) (5.9.0)
# Requirement already satisfied: accelerate in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 5)) (1.13.0)
# Requirement already satisfied: scikit-learn in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: matplotlib in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (3.10.9)
# Requirement already satisfied: seaborn in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: jupyter in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: pyarrow in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 10)) (24.0.0)
# Requirement already satisfied: umap-learn in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 11)) (0.5.12)
# Requirement already satisfied: plotly in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 12)) (6.7.0)
# Requirement already satisfied: nbformat in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 13)) (5.10.4)
# Requirement already satisfied: joblib in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 14)) (1.5.3)
# Requirement already satisfied: scipy in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from -r ../requirements.txt (line 15)) (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from pandas->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: filelock in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 3)) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->-r ../requirements.txt (line 3)) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch->-r ../requirements.txt (line 3)) (1.5.5)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: packaging>=20.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (0.22.2)
# Requirement already satisfied: typer in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from transformers->-r ../requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: anyio in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (4.13.0)
# Requirement already satisfied: certifi in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: idna in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (3.17)
# Requirement already satisfied: h11>=0.16 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers->-r ../requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from typer->transformers->-r ../requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from typer->transformers->-r ../requirements.txt (line 4)) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from typer->transformers->-r ../requirements.txt (line 4)) (0.0.4)
# Requirement already satisfied: psutil in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from accelerate->-r ../requirements.txt (line 5)) (7.2.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: notebook in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 9)) (7.5.6)
# Requirement already satisfied: jupyter-console in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 9)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 9)) (7.17.1)
# Requirement already satisfied: ipykernel in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 9)) (7.2.0)
# Requirement already satisfied: ipywidgets in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 9)) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter->-r ../requirements.txt (line 9)) (4.5.7)
# Requirement already satisfied: numba>=0.51.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from umap-learn->-r ../requirements.txt (line 11)) (0.65.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from umap-learn->-r ../requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from plotly->-r ../requirements.txt (line 12)) (2.22.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbformat->-r ../requirements.txt (line 13)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbformat->-r ../requirements.txt (line 13)) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbformat->-r ../requirements.txt (line 13)) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbformat->-r ../requirements.txt (line 13)) (5.15.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r ../requirements.txt (line 13)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r ../requirements.txt (line 13)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r ../requirements.txt (line 13)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r ../requirements.txt (line 13)) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->-r ../requirements.txt (line 13)) (4.10.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from numba>=0.51.2->umap-learn->-r ../requirements.txt (line 11)) (0.47.0)
# Requirement already satisfied: six>=1.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers->-r ../requirements.txt (line 4)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers->-r ../requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers->-r ../requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from sympy>=1.13.3->torch->-r ../requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: comm>=0.1.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (9.14.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (8.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipykernel->jupyter->-r ../requirements.txt (line 9)) (6.5.6)
# Requirement already satisfied: decorator>=5.1.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r ../requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 9)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 9)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jinja2->torch->-r ../requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: async-lru>=1.0.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.19.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.2.4)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.14.0)
# Requirement already satisfied: requests>=2.31 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: fqdn in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: isoduration in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: uri-template in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 9)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: webencodings in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: pycparser in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 9)) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: tzdata in /home/jules/.pyenv/versions/3.12.13/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 9)) (2026.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from scipy.stats import kruskal, mannwhitneyu
import matplotlib.patches as patches
import matplotlib.lines as lines
import os

# Create figures directory if it doesn't exist
os.makedirs("../figures", exist_ok=True)

# %% [markdown]
# ## Figure 1: Pipeline Figure
# Conceptual diagram of the methodology.

# %%
fig, ax = plt.subplots(figsize=(6, 8))
ax.axis('off')

boxes = [
    ("Prompt\n(e.g., 'cat', 'A>B')", 0.8),
    ("Transformer Model\n(e.g., GPT-2)", 0.6),
    ("Hidden States\n(layer 1 ... layer N)", 0.4),
    ("Trajectory Construction\n(L, D)", 0.2),
    ("Metrics & Dimensionality Reduction\n(Length, Convergence, UMAP)", 0.0)
]

for i, (text, y) in enumerate(boxes):
    box = patches.Rectangle((0.1, y - 0.05), 0.8, 0.1, fill=True, color='#e0f2f1', ec='#00695c', lw=2)
    ax.add_patch(box)
    ax.text(0.5, y, text, ha='center', va='center', fontsize=12, fontweight='bold', color='#004d40')
    if i < len(boxes) - 1:
        ax.annotate('', xy=(0.5, y - 0.05), xytext=(0.5, boxes[i+1][1] + 0.05),
                    arrowprops=dict(arrowstyle='->', lw=2, color='#00695c'))
        
plt.title("Methodology Pipeline", fontsize=14, fontweight='bold', y=0.95)
plt.tight_layout()
plt.savefig('../figures/figure1_pipeline.pdf', dpi=300, bbox_inches='tight')
plt.savefig('../figures/figure1_pipeline.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Figure 2: 3D Trajectory Manifold
# Visualizes trajectory evolution across layers for Animals, Objects (Vehicles), and Reasoning.

# %%
df_umap = pd.read_parquet('../results/projected/gpt2_umap.parquet')
groups_to_plot = ['animals', 'vehicles', 'reasoning']
df_filtered = df_umap[df_umap['group'].isin(groups_to_plot)].copy()
df_filtered['group'] = df_filtered['group'].replace({'vehicles': 'objects'})
color_map = {'animals': 'blue', 'objects': 'green', 'reasoning': 'red'}

# STATIC PLOT (Matplotlib)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

for group in color_map.keys():
    group_df = df_filtered[df_filtered['group'] == group]
    for prompt_id in group_df['prompt_id'].unique():
        traj = group_df[group_df['prompt_id'] == prompt_id].sort_values('layer')
        ax.plot(traj['x'], traj['y'], traj['z'], color=color_map[group], alpha=0.5, lw=1.5)
        ax.scatter(traj['x'], traj['y'], traj['z'], c=traj['layer'], cmap='viridis', s=20, alpha=0.8)

legend_elements = [lines.Line2D([0], [0], color=c, lw=2, label=g.capitalize()) for g, c in color_map.items()]
ax.legend(handles=legend_elements, loc='upper right')
ax.set_title("3D Trajectory Manifold (GPT-2)", fontsize=14, fontweight='bold')
ax.set_xlabel("UMAP 1")
ax.set_ylabel("UMAP 2")
ax.set_zlabel("UMAP 3")
plt.tight_layout()
plt.savefig('../figures/figure2_manifold.pdf', dpi=300, bbox_inches='tight')
plt.show()

# INTERACTIVE PLOT (Plotly)
fig_plotly = go.Figure()
for group in color_map.keys():
    group_df = df_filtered[df_filtered['group'] == group]
    for prompt_id in group_df['prompt_id'].unique():
        traj = group_df[group_df['prompt_id'] == prompt_id].sort_values('layer')
        fig_plotly.add_trace(go.Scatter3d(
            x=traj['x'], y=traj['y'], z=traj['z'],
            mode='lines+markers',
            line=dict(color=color_map[group], width=2),
            marker=dict(size=4, color=traj['layer'], colorscale='Viridis', opacity=0.8),
            name=f"{group} - {prompt_id}",
            showlegend=False
        ))
fig_plotly.update_layout(title="Interactive 3D Trajectory Manifold", scene=dict(xaxis_title='UMAP 1', yaxis_title='UMAP 2', zaxis_title='UMAP 3'))
fig_plotly.write_html('../figures/trajectory.html')
fig_plotly.show()

# %% [markdown]
# ## Figure 3: Convergence Metric
# Analyzes layerwise within-category vs between-category Euclidean distances in PCA space.

# %%
df_pca = pd.read_parquet('../results/projected/gpt2_pca.parquet')
layers = sorted(df_pca['layer'].unique())
categories = ['animals', 'vehicles', 'reasoning']

within_distances = []
between_distances = []

for l in layers:
    df_l = df_pca[df_pca['layer'] == l]
    centroids = {}
    for cat in categories:
        cat_data = df_l[df_l['group'] == cat][['x', 'y', 'z']].values
        if len(cat_data) > 0:
            centroid = np.mean(cat_data, axis=0)
            centroids[cat] = centroid
            dists = np.linalg.norm(cat_data - centroid, axis=1)
            for d in dists:
                within_distances.append({'layer': l, 'distance': d, 'type': 'Within Category'})
                
    cat_keys = list(centroids.keys())
    for i in range(len(cat_keys)):
        for j in range(i+1, len(cat_keys)):
            d = np.linalg.norm(centroids[cat_keys[i]] - centroids[cat_keys[j]])
            between_distances.append({'layer': l, 'distance': d, 'type': 'Between Category'})

df_within = pd.DataFrame(within_distances)
df_between = pd.DataFrame(between_distances)

within_mean = df_within.groupby('layer')['distance'].mean().values
within_std = df_within.groupby('layer')['distance'].std().values
between_mean = df_between.groupby('layer')['distance'].mean().values
between_std = df_between.groupby('layer')['distance'].std().values

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(layers, between_mean, label='Between Categories', color='red', marker='o')
ax.fill_between(layers, between_mean - between_std, between_mean + between_std, color='red', alpha=0.2)
ax.plot(layers, within_mean, label='Within Categories', color='blue', marker='s')
ax.fill_between(layers, within_mean - within_std, within_mean + within_std, color='blue', alpha=0.2)
ax.set_title("Layerwise Representation Convergence", fontsize=14, fontweight='bold')
ax.set_xlabel("Transformer Layer")
ax.set_ylabel("Mean PCA Euclidean Distance")
ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

# Statistical Significance Test (Mann-Whitney U)
for l in layers:
    w_dists = df_within[df_within['layer'] == l]['distance'].values
    b_dists = df_between[df_between['layer'] == l]['distance'].values
    
    if len(w_dists) > 0 and len(b_dists) > 0:
        stat, p_val = mannwhitneyu(w_dists, b_dists, alternative='two-sided')
        if p_val < 0.001:
            sig = '***'
        elif p_val < 0.01:
            sig = '**'
        elif p_val < 0.05:
            sig = '*'
        else:
            sig = ''
        if sig:
            ax.annotate(sig, xy=(l, max(between_mean[l-1], within_mean[l-1]) + 50), ha='center', fontsize=12, color='black')

plt.tight_layout()
plt.savefig('../figures/figure3_convergence.pdf', dpi=300)
plt.show()

# %% [markdown]
# ## Figure 4: Curvature Analysis
# Compares non-linearity of trajectories across specific categories.

# %%
df_metrics = pd.read_csv('../results/metrics/phase_7_controls_metrics/gpt2_trajectory_metrics.csv')
df_plot = df_metrics[df_metrics['category'].isin(['animals', 'vehicles', 'reasoning'])].copy()
df_plot['category'] = df_plot['category'].replace({'vehicles': 'objects'})

groups = [df_plot[df_plot['category'] == cat]['curvature'].values for cat in df_plot['category'].unique()]
stat, p_val = kruskal(*groups)

fig, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x='category', y='curvature', data=df_plot, ax=ax, hue='category', palette={'animals': 'blue', 'objects': 'green', 'reasoning': 'red'}, legend=False)
ax.set_title("Trajectory Curvature Analysis by Category", fontsize=14, fontweight='bold')
ax.set_xlabel("Prompt Category")
ax.set_ylabel("Curvature ($\kappa$)")
ax.text(0.5, 0.95, f"Kruskal-Wallis p-value: {p_val:.2e}" + (" (***)" if p_val < 0.001 else ""), 
        transform=ax.transAxes, ha='center', fontsize=12, bbox=dict(facecolor='white', alpha=0.8))
plt.tight_layout()
plt.savefig('../figures/figure4_curvature.pdf', dpi=300)
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\k'
# <>:12: SyntaxWarning: invalid escape sequence '\k'
# /tmp/ipykernel_87147/2288065810.py:12: SyntaxWarning: invalid escape sequence '\k'
#   ax.set_ylabel("Curvature ($\kappa$)")

# %% [markdown]
# ## Figure 5: Control Experiments
# Validates trajectory structure against label shuffling, random embeddings, and layer shuffling.

# %%
df_shuffle = pd.read_csv('../results/controls/gpt2_label_shuffle.csv')
df_real = pd.read_csv('../results/controls/gpt2_real_silhouette.csv')
df_rand = pd.read_csv('../results/controls/gpt2_random_embeddings.csv')
df_layer_shuffle = pd.read_csv('../results/controls/gpt2_layer_shuffle.csv')

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle("Control Experiments vs Real Data", fontsize=16, fontweight='bold')

axes[0, 0].plot(df_real['layer'], df_real['score'], marker='o', color='blue', label='Real Data')
axes[0, 0].set_title("A: Real Data Convergence")
axes[0, 0].set_xlabel("Layer")
axes[0, 0].set_ylabel("Silhouette Score")
axes[0, 0].grid(True, linestyle='--', alpha=0.5)

axes[1, 1].plot(df_shuffle['layer'], df_shuffle['real_score'], marker='o', color='blue', label='Real Labels')
axes[1, 1].plot(df_shuffle['layer'], df_shuffle['null_mean'], marker='s', color='grey', label='Shuffled Labels')
axes[1, 1].fill_between(df_shuffle['layer'], df_shuffle['null_mean'] - df_shuffle['null_std'], df_shuffle['null_mean'] + df_shuffle['null_std'], color='grey', alpha=0.3)
axes[1, 1].set_title("D: Prompt Label Shuffle")
axes[1, 1].set_xlabel("Layer")
axes[1, 1].set_ylabel("Silhouette Score")
axes[1, 1].legend()
axes[1, 1].grid(True, linestyle='--', alpha=0.5)

axes[0, 1].plot(df_real['layer'], df_real['score'], marker='o', color='blue', label='Real Data', alpha=0.3)
axes[0, 1].plot(df_rand['layer'], df_rand['score'], marker='x', color='red', linestyle='--', label='Random Embeddings')
axes[0, 1].set_title("B: Random Embeddings")
axes[0, 1].set_xlabel("Layer")
axes[0, 1].set_ylabel("Structure Metric")
axes[0, 1].legend()
axes[0, 1].grid(True, linestyle='--', alpha=0.5)

axes[1, 0].plot(df_real['layer'], df_real['score'], marker='o', color='blue', label='Ordered Layers', alpha=0.3)
axes[1, 0].plot(df_layer_shuffle['layer'], df_layer_shuffle['score'], marker='x', color='orange', label='Shuffled Layers')
axes[1, 0].set_title("C: Layer Shuffle")
axes[1, 0].set_xlabel("Layer")
axes[1, 0].set_ylabel("Structure Metric")
axes[1, 0].legend()
axes[1, 0].grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig('../figures/figure5_controls.pdf', dpi=300)
plt.show()
